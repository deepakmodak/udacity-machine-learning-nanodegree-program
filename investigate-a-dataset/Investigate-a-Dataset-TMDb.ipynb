# %% [markdown]
# # Investigate a Dataset : TMDb Movie Data
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda1">Data Analysis : 1</a></li>
# <li><a href="#eda2">Data Analysis : 2</a></li>
# <li><a href="#eda3">Data Analysis : 3</a></li>
# <li><a href="#eda4">Data Analysis : 4</a></li>
# <li><a href="#limitations">Limitations</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>
#
# <a id='intro'></a>
# ## Introduction
#
# > TMDb Movie data contains information about movies, cast, director, ratings etc.
# > Associations and Effects for directors are evaluated in this analysis
# > Some questions to be answered are:
# - Name a few popular directors.
# - What are typical runtimes for directors?
# - Is there a duration preferred by directors?
# - What are typical revenues for directors? Who are the most successful directors?
# - Is there a relation between popularity and revenue for directors?

# %%
#import required packages
import pandas as pd
import csv # read and write csv files
from datetime import datetime # operations to parse dates
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### General Properties
# **Observations**
# - Rows: 10866
# - Columns: 21
# - Null values  present in variables: [as inspected in code below]
# > - imdb_id
# > - cast
# > - homepage
# > - director
# > - tagline
# > - keywords
# > - overview
# > - genres
# > - production_companies
#
# **Data cleaning done**
# - One duplicate record is present and is deleted.
# - Of the different variables, imdb_id is significant to identify the records uniquely. Only 10 of 10865 are missing. Hence, we only drop the records with this value as missing.
# - In this analysis, we are inspecting directors and any relation to other given variables. So, we also drop rows with missing values for this column.
# - Other values with missing values are not significant, hence not touched.

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.
df = pd.read_csv('tmdb-movies.csv', encoding='utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %% [markdown]
# #### Data Cleaning: Duplicates

# %%
# check number of duplicate records
sum(df.duplicated())
# Out:
# 1

# %%
# drop rows that are duplicates and save in dataset itself 
df.drop_duplicates(inplace=True)

# %%
#inspect dataset to confirm 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10865 non-null int64
# imdb_id                 10855 non-null object
# popularity              10865 non-null float64
# budget                  10865 non-null int64
# revenue                 10865 non-null int64
# original_title          10865 non-null object
# cast                    10789 non-null object
# homepage                2936 non-null object
# director                10821 non-null object
# tagline                 8041 non-null object
# keywords                9372 non-null object
# overview                10861 non-null object
# runtime                 10865 non-null int64
# genres                  10842 non-null object
# production_companies    9835 non-null object
# release_date            10865 non-null object
# vote_count              10865 non-null int64
# vote_average            10865 non-null float64
# ...

# %% [markdown]
# #### Data Wrangling: Null Values

# %%
# check columns with null values
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7929
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# #### Data Cleaning :Dropping duplicate rows

# %%
# After viewing the structure of the TMDb dataset and deleting duplicate records
#   we perform cleaning steps in this second part.
# Here, we are removing rows with null values in imdb_id column and directors only
df.dropna(subset=['imdb_id'], inplace=True) 
df.dropna(subset=['director'], inplace=True) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10815 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10815 non-null int64
# imdb_id                 10815 non-null object
# popularity              10815 non-null float64
# budget                  10815 non-null int64
# revenue                 10815 non-null int64
# original_title          10815 non-null object
# cast                    10745 non-null object
# homepage                2925 non-null object
# director                10815 non-null object
# tagline                 8029 non-null object
# keywords                9353 non-null object
# overview                10812 non-null object
# runtime                 10815 non-null int64
# genres                  10795 non-null object
# production_companies    9812 non-null object
# release_date            10815 non-null object
# vote_count              10815 non-null int64
# vote_average            10815 non-null float64
# ...

# %%
#check dataset 
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# #### Data Wrangling
# Inspecting the Values in Directors Columns. As factor of 'Directors' is the basis of our analysis, we want to check if values in this column correspond to only inidvidual directors or collaborations or a mix of both.

# %%
#check unique values of directors
df['director'].value_counts()
# Out:
# Woody Allen                       45
# Clint Eastwood                    34
# Steven Spielberg                  29
# Martin Scorsese                   29
# Ridley Scott                      23
# Ron Howard                        22
# Steven Soderbergh                 22
# Joel Schumacher                   21
# Brian De Palma                    20
# Tim Burton                        19
# Wes Craven                        19
# Barry Levinson                    19
# Mike Nichols                      18
# John Carpenter                    18
# Rob Reiner                        18
# David Cronenberg                  18
# Stephen Frears                    17
# Francis Ford Coppola              17
# Tyler Perry                       17
# Peter Hyams                       17
# Renny Harlin                      17
# Walter Hill                       17
# Oliver Stone                      17
# Robert Zemeckis                   17
# Norman Jewison                    17
# ...

# %% [markdown]
# There are very few records with multiple directors. Hence, we leave them as it is. Assumption is that personal preferences and styles might change in collaborative ventures.

# %%
# save new clean dataset for next section
df.to_csv('tmdb-movies-cleaned.csv', index=False)

# %% [markdown]
# <a id='eda1'></a>
# ## Exploratory Data Analysis
#
# ### Analysis 1
# ##### Name a few popular directors.

# %%
# Importing data from newly cleaned dataset
df_dir = pd.read_csv('tmdb-movies-cleaned.csv')
df_dir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10815 entries, 0 to 10814
# Data columns (total 21 columns):
# id                      10815 non-null int64
# imdb_id                 10815 non-null object
# popularity              10815 non-null float64
# budget                  10815 non-null int64
# revenue                 10815 non-null int64
# original_title          10815 non-null object
# cast                    10745 non-null object
# homepage                2925 non-null object
# director                10815 non-null object
# tagline                 8029 non-null object
# keywords                9353 non-null object
# overview                10812 non-null object
# runtime                 10815 non-null int64
# genres                  10795 non-null object
# production_companies    9812 non-null object
# release_date            10815 non-null object
# vote_count              10815 non-null int64
# vote_average            10815 non-null float64
# ...

# %%
# we take counts of releases for every director
pop_dir = df_dir['director'].value_counts()
pop_dir[:5]
# Out:
# Woody Allen         45
# Clint Eastwood      34
# Steven Spielberg    29
# Martin Scorsese     29
# Ridley Scott        23
# Name: director, dtype: int64

# %% [markdown]
# This shows us the directors with maximum releases over the years but is not indicative of popularity. Hence, we try grouping by director names to gauge the popularity better.

# %%
# save dataframe grouped by directors separately
# so that we can take consider every director's releases over the years together
# this is to see each directors efforts holistically
director_df = df_dir.groupby('director') 
dir_mean_df = director_df.mean()
dir_mean_df
# Out:
#                                                                id  popularity  \
# director
#  Fr̩d̩ric Jardin                                   79070.000000    0.434506
# A. Todd Smith                                       370687.000000    1.876037
# A.R. Murugadoss                                      14070.000000    0.215030
# Aaron Aites                                          36124.000000    0.108700
# Aaron Blaise|Robert Walker                           10009.000000    1.653031
# Aaron Hann|Mario Miscione                           335866.000000    0.350599
# Aaron Harvey                                         75736.000000    1.212003
# Aaron Katz|Martha Stephens                          252102.000000    0.267446
# Aaron Keeling|Austin Keeling                        326247.000000    0.078363
# Aaron Moorhead|Justin Benson                        241855.000000    0.383406
# Aaron Norris                                         27370.000000    0.158442
# ...

# %%
director_df.median()
# Out:
#                                                           id  popularity  \
# director
#  Fr̩d̩ric Jardin                                   79070.0    0.434506
# A. Todd Smith                                       370687.0    1.876037
# A.R. Murugadoss                                      14070.0    0.215030
# Aaron Aites                                          36124.0    0.108700
# Aaron Blaise|Robert Walker                           10009.0    1.653031
# Aaron Hann|Mario Miscione                           335866.0    0.350599
# Aaron Harvey                                         75736.0    1.212003
# Aaron Katz|Martha Stephens                          252102.0    0.267446
# Aaron Keeling|Austin Keeling                        326247.0    0.078363
# Aaron Moorhead|Justin Benson                        241855.0    0.383406
# Aaron Norris                                         27352.0    0.144296
# Aaron Schneider                                      44718.0    0.661465
# ...

# %%
#set the size of all histograms
fig_size = plt.rcParams["figure.figsize"]
print("Current size:", fig_size)
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
print("Current size:", fig_size)
# Out:
# Current size: [12.0, 9.0]
# Current size: [12, 9]

# %%
#Create basic histograms
df_dir.hist(bins=10);

# %%
# we plot a histogram of each popularity garnered by directors
dir_mean_df['popularity'].hist();
plt.xlabel('Popularity')
plt.ylabel('Counts')
plt.title('Popularity Over the Years');

# %%
# inspecting the statistics for the popularity of directors as a whole
#for thsi we take statistics for the dataset grouped by 'director' variable which was created in preceding steps
dir_mean_df['popularity'].describe()
# Out:
# count    5064.000000
# mean        0.511897
# std         0.694520
# min         0.000973
# 25%         0.190121
# 50%         0.339477
# 75%         0.579055
# max        16.696886
# Name: popularity, dtype: float64

# %%
# directors with maximum popularity ratings
dir_mean_df['popularity'].nlargest(10)
# Out:
# director
# Colin Trevorrow                16.696886
# Joe Russo|Anthony Russo        12.971027
# Chad Stahelski|David Leitch    11.422751
# Don Hall|Chris Williams         8.691294
# Juno John Lee                   8.411577
# Kyle Balda|Pierre Coffin        7.404165
# Alan Taylor                     6.883129
# Peter Richardson                6.668990
# Pete Docter                     6.326804
# Christopher Nolan               6.195521
# Name: popularity, dtype: float64

# %%
dir_mean_df[880:900]#double check values
# Out:
#                                                           id  popularity  \
# director
# Clive A. Smith                                      21356.00    0.195539
# Clive Barker                                        12819.00    0.321329
# Clive Donner                                        23138.25    0.250399
# Clyde Geronimi|Hamilton Luske|Wolfgang Reitherman   12230.00    2.631987
# Cl̩ment Virgo                                      14174.00    1.203532
# Cody Calahan                                       207780.00    0.258887
# Cody Cameron                                        51170.00    0.484243
# Cody Cameron|Kris Pearn                            109451.00    0.932599
# Coky Giedroyc                                      148110.50    0.131463
# Coley Sohn                                         138907.00    0.034628
# Colin Chilvers|Jerry Kramer|Jim Blashfield          13192.00    0.321068
# Colin Eggleston                                     39995.00    0.047645
# ...

# %% [markdown]
# ### Observations on Popularity:
# - We have here the list of ten most popular directors.
# - We also see that most directors score between 0 and 1 as per popularity.
# - The distribution is very skewed to the right.

# %% [markdown]
# <a id='eda2'></a>
#
# ## Exploratory Data Analysis
#
# ### Analysis 2
# #### What are typical runtimes for directors? Is there a duration preferred by directors?

# %%
dir_mean_df['runtime'].describe()
# Out:
# count    5064.000000
# mean       97.942123
# std        33.439046
# min         0.000000
# 25%        89.000000
# 50%        96.000000
# 75%       106.000000
# max       900.000000
# Name: runtime, dtype: float64

# %%
dir_mean_df['runtime'].hist(bins=100);
plt.xlabel('Runtime')
plt.ylabel('Counts')
plt.title('Runtime Over the Years');

# %% [markdown]
# #### Observations- Runtime:
# - The popular runtime across directors is 100-110 as seen in the visualization.
# - This is also verified by our quartile percentages.
# - The distribution is skewed to the right.

# %% [markdown]
# <a id='eda3'></a>
#
# ## Exploratory Data Analysis
#
# ### Analysis 3
# #### What are typical revenues for directors? Who are the most successful directors?
# Steps:
# - To answer this question, we view the revenue variable from our dataset grouped over the director factor.

# %%
dir_mean_df['revenue'].describe()
# Out:
# count    5.064000e+03
# mean     2.297306e+07
# std      7.654512e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      9.658396e+06
# max      1.156731e+09
# Name: revenue, dtype: float64

# %%
rev = dir_mean_df['revenue']
rev_new = rev / (1e8)
rev_new.hist(bins=100);
plt.xlabel('Revenue')
plt.ylabel('Counts')
plt.title('Revenue Over the Years');

# %%
dir_mean_df['revenue_adj'].hist(bins=100);

# %%
# directors with maximum revenues
dir_mean_df['revenue'].nlargest(10)
# Out:
# director
# Kyle Balda|Pierre Coffin                     1.156731e+09
# Lee Unkrich                                  1.063172e+09
# Andrew Adamson|Kelly Asbury|Conrad Vernon    9.198388e+08
# Andrew Stanton|Lee Unkrich                   8.646260e+08
# Pete Docter                                  8.537086e+08
# David Yates                                  8.308591e+08
# Chris Miller|Raman Hui                       7.989582e+08
# Roger Allers|Rob Minkoff                     7.882418e+08
# Colin Trevorrow                              7.587683e+08
# Robert Stromberg                             7.584104e+08
# Name: revenue, dtype: float64

# %%
# directors with maximum revenue_adj
dir_mean_df['revenue_adj'].nlargest(10)
# Out:
# director
# Clyde Geronimi|Hamilton Luske|Wolfgang Reitherman    1.574815e+09
# Roger Allers|Rob Minkoff                             1.159592e+09
# Kyle Balda|Pierre Coffin                             1.064192e+09
# Lee Unkrich                                          1.063172e+09
# Andrew Adamson|Kelly Asbury|Conrad Vernon            1.061904e+09
# George Lucas                                         1.052320e+09
# Andrew Stanton|Lee Unkrich                           1.024887e+09
# Chris Miller|Raman Hui                               8.402392e+08
# David Yates                                          8.354911e+08
# Pete Docter                                          7.854116e+08
# Name: revenue_adj, dtype: float64

# %% [markdown]
# #### Observations- Revenue:
# - The popular revenue across directors is 0.01e8 to 0.1e8 as seen in the visualization.
# - This is also verified by our quartile percentages.
# - The distribution is skewed to the right.

# %% [markdown]
# <a id='eda4'></a>
#
# ## Exploratory Data Analysis
#
# ### Analysis 4
# #### Is there a relation between popularity and revenue for directors?
# Steps:
# - To answer this question, we visualize the revenue and popularity variable from our dataset grouped over the director factor.

# %%
# plotting popularity and revenue of directors
plt.scatter(x=dir_mean_df['popularity'], y=dir_mean_df['revenue']);
plt.xlabel('Popularity')
plt.ylabel('Revenue')
plt.title('Popularity vs Revenue');

# %%
# computing correlation, if any, among variables in the dataset grouped by 'directors'
dir_mean_df.corr(method='pearson')
# Out:
#                     id  popularity    budget   revenue   runtime  vote_count  \
# id            1.000000   -0.044878 -0.154395 -0.104452 -0.061491   -0.051312
# popularity   -0.044878    1.000000  0.579946  0.679109  0.052462    0.811656
# budget       -0.154395    0.579946  1.000000  0.774930  0.096742    0.690545
# revenue      -0.104452    0.679109  0.774930  1.000000  0.064979    0.830514
# runtime      -0.061491    0.052462  0.096742  0.064979  1.000000    0.071334
# vote_count   -0.051312    0.811656  0.690545  0.830514  0.071334    1.000000
# vote_average -0.022830    0.157441  0.096692  0.153495  0.100968    0.211894
# release_year  0.538960    0.062540  0.035670  0.023623 -0.110586    0.082199
# budget_adj   -0.193834    0.545452  0.966103  0.739031  0.125416    0.642083
# revenue_adj  -0.140135    0.630990  0.704794  0.936411  0.083880    0.761461
#
#               vote_average  release_year  budget_adj  revenue_adj
# ...

# %% [markdown]
# Observations:
# - We see from our scatterplot and correlation that popularity and revenue for directors is positively correlated, but not very significantly.
# - But we do notice that for at lower values, the relation is significant.
# - However, this is purely correlation and not to be inferred as causal.
# - It does point us to a line of investigation that we can take up for detailed assessment.

# %% [markdown]
# <a id='limitations'></a>
# ## Limitations
# - In the above analysis, we have worked with runtimes, popularity and revenues.
# - Dataset is not exhaustive and hence, results or inferences are not absolute. i.e The dataset does not confirm that every release of every director is listed. Findings are limited to datset only.
# - We restrict ourselves to only numerical values of revenues. Any variances in currencies, like dollars, rupees, Euros, etc. are not considered.
# - Vote counts are taken at face value. We are not inspecting the nature of votes, good or bad or any other range of values. Also, the period or channels in which these vote counts were gathered is not considered and will be significant if varying for different movies.
# - The medium through which popularity was determined is unknown. This can impact the analysis as the limitations and bias, inherent while gauging audience response, will be present in the end values too.
# - New and veteran directors are treated alike. Skew is possible due to directors having multiple releases in a single year or releases over many years over new directors or directors with fewer releases every year.
# - While we did not have missing values for any of the factors under consideration, we acknowledge the presence of these limitations and assumptions in our analysis.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# - From our exercise, we discovered that there are *patterns to runtimes, popularity and revenues of directors*.
# - While only tentative, we found that popular runtimes range between 100 and 110 minutes.
# - Also, ratings for directors had maximum likelihood of being in the 0 to 1 range.
# - Revenues showed a wider range, but the most likely range was 0.01e8 to 0.1e8.
# - We also analyzed who the most successful directors were popularity-wise and revenue-wise.
# - However, these analysis do not account for collaborations.
# - These lines of analysis point us to the need for further investigation, especially with regards to revenue and popularity.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate-a-Dataset-TMDb.ipynb'])
# Out:
# 0
